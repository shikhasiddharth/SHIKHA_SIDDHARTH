# %% [markdown]
# <a href="https://colab.research.google.com/github/shikhasiddharth/SHIKHA_SIDDHARTH/blob/main/Mapup.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
def generate_car_matrix(input_df):
  print("shape of the dataframe:")
  print(input_df.shape)
df = pd.read_csv('dataset-1.csv')
generate_car_matrix(df)
print(df)
# Out:
# shape of the dataframe:
# (341, 8)
#      id_1  id_2  route   moto    car     rv   bus  truck
# 0     829   827      1   2.05   4.14   4.14  10.1   15.2
# 1     829   821      4   6.63  13.26  13.26  32.4   48.5
# 2     829   804      7  14.41  28.92  28.92  64.7   97.0
# 3     829   822      6   5.90  11.81  11.81  28.8   43.2
# 4     829   826      9   2.87   5.81   5.81  14.2   21.2
# ..    ...   ...    ...    ...    ...    ...   ...    ...
# 336   803   802      3   1.70   3.40   3.40   6.9   10.3
# 337   803   805      4   3.00   6.00   6.00  12.0   17.9
# 338   803   825      3  11.59  23.28  23.28  50.1   75.2
# 339   803   806      9   3.80   7.70   7.70  15.3   23.0
# 340   803   830      1  16.18  32.47  32.47  72.6  108.8
#
# [341 rows x 8 columns]

# %%
pip install pandas

# %%
for idx in df.index:
  df.at[idx, idx] = 0
# Out:
# <ipython-input-18-07c8626110bd>:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df.at[idx, idx] = 0
# <ipython-input-18-07c8626110bd>:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df.at[idx, idx] = 0
# <ipython-input-18-07c8626110bd>:2: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
# ...

# %%
print(df)
# Out:
#      id_1  id_2  route   moto    car     rv   bus  truck    0    1  ...  331  \
# 0     829   827      1   2.05   4.14   4.14  10.1   15.2  0.0  NaN  ...  NaN
# 1     829   821      4   6.63  13.26  13.26  32.4   48.5  NaN  0.0  ...  NaN
# 2     829   804      7  14.41  28.92  28.92  64.7   97.0  NaN  NaN  ...  NaN
# 3     829   822      6   5.90  11.81  11.81  28.8   43.2  NaN  NaN  ...  NaN
# 4     829   826      9   2.87   5.81   5.81  14.2   21.2  NaN  NaN  ...  NaN
# ..    ...   ...    ...    ...    ...    ...   ...    ...  ...  ...  ...  ...
# 336   803   802      3   1.70   3.40   3.40   6.9   10.3  NaN  NaN  ...  NaN
# 337   803   805      4   3.00   6.00   6.00  12.0   17.9  NaN  NaN  ...  NaN
# 338   803   825      3  11.59  23.28  23.28  50.1   75.2  NaN  NaN  ...  NaN
# 339   803   806      9   3.80   7.70   7.70  15.3   23.0  NaN  NaN  ...  NaN
# 340   803   830      1  16.18  32.47  32.47  72.6  108.8  NaN  NaN  ...  NaN
#
# ...
